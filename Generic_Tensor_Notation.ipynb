# %%
# jelaskan tentang perintah ini
# images_pt = torch.zeros([32, 28, 28, 3])

print("Fungsi torch.zeros dipakai untuk membentuk tensor yang seluruh isinya bernilai 0,")
print("dengan kapasitas 32 sampel gambar, resolusi 28x28 piksel, dan 3 channel warna (RGB).")
print("Biasanya, tensor semacam ini dimanfaatkan sebagai nilai awal (inisialisasi) atau placeholder")
print("saat kita melakukan pemrosesan gambar menggunakan PyTorch.")
# Out:
# Fungsi torch.zeros dipakai untuk membentuk tensor yang seluruh isinya bernilai 0,
# dengan kapasitas 32 sampel gambar, resolusi 28x28 piksel, dan 3 channel warna (RGB).
# Biasanya, tensor semacam ini dimanfaatkan sebagai nilai awal (inisialisasi) atau placeholder
# saat kita melakukan pemrosesan gambar menggunakan PyTorch.
