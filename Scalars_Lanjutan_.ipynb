# %%
# 1. buat variabel skalar x dan simpan suatu nilai skalar
x = 27
x
# Out:
# 27

# %%
# tampilkan tipe data dari x
type(x)
# Out:
# int

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y = 277

# %%
# tampilkan tipe data dari y
type(y)
# Out:
# int

# %%
# jumlahkan x+y
py_sum = x + y
py_sum
# Out:
# 304

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 0.27

# %%
# jumlahkan x_float dengan y
x_float = 0.27
float_sum = x_float + y
float_sum
# Out:
# 277.27

# %%
# tampilkan tipe data dari x_float
type(x_float)
# Out:
# float

# %% [markdown]
# 2. lakukan tahapan pada soal 1 dengan menggunakan tensorflow

# %%
import tensorflow as tf

# %%
# buat variabel skalar x dan simpan suatu nilai skalar
# tampilkan tipe data dari x
x_tf = tf.Variable(27, dtype=tf.int16)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=27>

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
# tampilkan tipe data dari y
y_tf = tf.Variable(277, dtype=tf.int16)
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=277>

# %%
# jumlahkan x+y
tf_sum = x_tf + y_tf
tf_sum
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=304>

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
# tampilkan tipe data dari x_float
x_float = tf.Variable(27., dtype=tf.float16)
x_float
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float16, numpy=27.0>

# %%
# jumlahkan x_float dengan y

# %% [markdown]
# 3. lakukan tahapan pada soal 1 dengan menggunakan pytorch

# %%
import torch

# %%
# buat variabel skalar x dan simpan suatu nilai skalar
x_pt = torch.tensor(27)
x_pt
# Out:
# tensor(27)

# %%
# tampilkan tipe data dari x
type(x_pt)
# Out:
# torch.Tensor

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y_pt = torch.tensor(277)
y_pt
# Out:
# tensor(277)

# %%
# tampilkan tipe data dari y
type(y_pt)
# Out:
# torch.Tensor

# %%
# jumlahkan x+y
pt_sum = x_pt + y_pt
pt_sum
# Out:
# tensor(304)

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = torch.tensor(0.27)
x_float
# Out:
# tensor(0.2700)

# %%
# jumlahkan x_float dengan y
pt_sum = x_float + y_pt
pt_sum
# Out:
# tensor(277.2700)

# %%
# tampilkan tipe data dari x_float
type(x_float)
# Out:
# torch.Tensor
