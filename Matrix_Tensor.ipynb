# %%
import numpy as np

# %%
# 1. buat matrix X berukuran 2x3 menggunakan numpy
X = np.array([[27, 2, 7], [22, 7, 77]])
X
# Out:
# array([[27,  2,  7],
#        [22,  7, 77]])

# %%
# Tampilkan ukuran dari matrix X
X.shape
# Out:
# (2, 3)

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
X[:,0]
# Out:
# array([27, 22])

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X
X[1,:]
# Out:
# array([22,  7, 77])

# %% [markdown]
# 2. ulangi soal nomor 1 menggunakan pytorch

# %%
import torch

# %%
# buat matrix X berukuran 2x3 menggunakan pytorch
X = torch.tensor([[27, 2, 7], [22, 7, 77]])
X
# Out:
# tensor([[27,  2,  7],
#         [22,  7, 77]])

# %%
# Tampilkan ukuran dari matrix X
X.shape
# Out:
# torch.Size([2, 3])

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
X[:, 0]
# Out:
# tensor([27, 22])

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X
X[1, :]
# Out:
# tensor([22,  7, 77])

# %% [markdown]
# 3. ulangi soal nomor 1 menggunakan tensorflow

# %%
import tensorflow as tf

# %%
# buat matrix X berukuran 2x3 menggunakan tensorflow
X_tf = tf.Variable([[27, 2, 7], [22, 7, 77]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[27,  2,  7],
#        [22,  7, 77]], dtype=int32)>

# %%
# Tampilkan ukuran dari matrix X
tf.shape(X_tf)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([2, 3], dtype=int32)>

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
X_tf[:, 0]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([27, 22], dtype=int32)>

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X
X_tf[1,:]
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([22,  7, 77], dtype=int32)>
